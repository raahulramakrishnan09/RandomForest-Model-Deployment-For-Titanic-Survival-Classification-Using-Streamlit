# %%
# !pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 44.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.70.124.163

# %%
# %%writefile web.py
# Out:
# Writing web.py

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.427s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run web.py & npx localtunnel --port 8501
# Out:
# [..................] \ fetchMetadata: sill resolveWithNewModule localtunnel@2.0
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.70.124.163:8501
#
# npx: installed 22 in 2.165s
# your url is: https://witty-doodles-fetch.loca.lt
# 2024-07-02 15:13:26.416 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 5, in <module>
#     model=joblib.load('KNN.joblib')
#   File "/usr/local/lib/python3.10/dist-packages/joblib/numpy_pickle.py", line 650, in load
#     with open(filename, 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'KNN.joblib'
# 2024-07-02 15:21:42.925 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 9, in <module>
#     df[col]=a.fit_transform(df[col])
# NameError: name 'df' is not defined
# 2024-07-02 15:22:13.130 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 9, in <module>
#     df[col]=a.fit_transform(df[col])
# NameError: name 'df' is not defined
# 2024-07-02 15:22:42.965 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 11, in <module>
#     df[col]=a.fit_transform(df[col])
# NameError: name 'df' is not defined
# 2024-07-02 15:22:42.974 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 11, in <module>
#     df[col]=a.fit_transform(df[col])
# NameError: name 'df' is not defined
# 2024-07-02 15:31:12.785 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 56, in main
#     st.success(diagnosis)
# NameError: name 'diagnosis' is not defined
# 2024-07-02 15:33:13.013 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 35, in main
#     Sex=st.selec('Sex')
# AttributeError: module 'streamlit' has no attribute 'selec'
# 2024-07-02 15:33:35.679 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 35, in main
#     Sex=st.select('choose',['Male','Female'])
# AttributeError: module 'streamlit' has no attribute 'select'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 15:36:51.435 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 54, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 20, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 15:37:57.081 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 55, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 20, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 15:37:59.928 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 55, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 20, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 15:39:02.812 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 55, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 20, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: ''
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 15:40:40.608 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 61, in <module>
#     main()
#   File "/content/web.py", line 56, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 20, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:09:27.524 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 54, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 18, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:12:38.068 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 54, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 18, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:14:09.684 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 16, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 806, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 910, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:15:15.770 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 53, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 806, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 910, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:16:28.488 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 53, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 806, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 910, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# 2024-07-02 16:19:22.569 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 7, in <module>
#     model=joblib.read('KNN.joblib')
# AttributeError: module 'joblib' has no attribute 'read'
# 2024-07-02 16:38:43.098 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=st.selectbox('select option')
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: SelectboxMixin.selectbox() missing 1 required positional argument: 'options'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:39:46.044 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 806, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 910, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:40:54.624 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py", line 234, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py", line 806, in kneighbors
#     X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 910, in check_array
#     raise ValueError(
# ValueError: dtype='numeric' is not compatible with arrays of bytes/strings.Convert your data to numeric values explicitly instead.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:51:40.817 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Female'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:54:47.186 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 16:55:33.359 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 17:01:12.130 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 52, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# 2024-07-02 17:11:43.328 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 36, in main
#     Embarked=st.text_input('Embarked',a.classes_)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/text_widgets.py", line 227, in text_input
#     return self._text_input(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/text_widgets.py", line 267, in _text_input
#     check_session_state_rules(default_value=None if value == "" else value, key=key)
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 17:15:41.734 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 53, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 17:16:11.576 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 53, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: 'Male'
# 2024-07-02 17:31:14.043 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 57, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.select('Embarked')
# AttributeError: module 'streamlit' has no attribute 'select'
# 2024-07-02 17:32:28.969 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.select('Embarked')
# AttributeError: module 'streamlit' has no attribute 'select'
# 2024-07-02 17:32:36.914 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.select('Embarked')
# AttributeError: module 'streamlit' has no attribute 'select'
# 2024-07-02 17:32:43.145 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.selectbpx('Embarked')
# AttributeError: module 'streamlit' has no attribute 'selectbpx'
# 2024-07-02 17:32:44.075 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.selectbpx('Embarked')
# AttributeError: module 'streamlit' has no attribute 'selectbpx'
# 2024-07-02 17:33:13.155 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.selectbox('Embarked')
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: SelectboxMixin.selectbox() missing 1 required positional argument: 'options'
# 2024-07-02 17:33:54.630 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.selectbox('Embarked',)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: SelectboxMixin.selectbox() missing 1 required positional argument: 'options'
# 2024-07-02 17:34:45.951 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 55, in <module>
#     main()
#   File "/content/web.py", line 34, in main
#     Embarked=st.selectbox('Embarked',)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: SelectboxMixin.selectbox() missing 1 required positional argument: 'options'
# 2024-07-02 17:53:48.703 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 56, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:53:56.939 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 56, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:01.511 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 56, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([])
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:04.998 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 56, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:13.167 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 56, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:20.251 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:43.183 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:43.929 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:54:52.738 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:55:54.066 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:55:56.898 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:55:58.029 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:55:59.174 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:56:03.086 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:56:06.989 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 58, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     Sex=sex_encoder.fit_transform([Sex])[0]
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:59:07.782 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 32, in main
#     sex_
# NameError: name 'sex_' is not defined
# 2024-07-02 17:59:12.300 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 32, in main
#     sex_encoder
# NameError: name 'sex_encoder' is not defined
# 2024-07-02 17:59:16.855 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 32, in main
#     sex_encoder=Label
# NameError: name 'Label' is not defined
# 2024-07-02 17:59:24.268 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 38, in main
#     Embarked=embarked_encoder.fit_transform([Embarked])[0]
# NameError: name 'embarked_encoder' is not defined
# 2024-07-02 17:59:43.186 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 33, in main
#     embarked_encoder
# NameError: name 'embarked_encoder' is not defined
# 2024-07-02 17:59:47.319 Uncaught app exception
# ...
#     exec(code, module.__dict__)
#   File "/content/web.py", line 62, in <module>
#     main()
#   File "/content/web.py", line 32, in main
#     Parch=st.number_input('Pclass',0,5)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/number_input.py", line 248, in number_input
#     return self._number_input(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/elements/widgets/number_input.py", line 457, in _number_input
#     widget_state = register_widget(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 167, in register_widget
#     return register_widget_from_metadata(metadata, ctx, widget_func_name, element_type)
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/state/widgets.py", line 212, in register_widget_from_metadata
#     raise DuplicateWidgetID(
# streamlit.errors.DuplicateWidgetID: There are multiple identical `st.number_input` widgets with the
# same generated key.
#
# When a widget is created, it's assigned an internal key based on
# its structure. Multiple widgets with an identical structure will
# result in the same internal key, which causes this error.
#
# To fix this error, please pass a unique `key` argument to
# `st.number_input`.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [0]
# 2024-07-02 19:50:31.292 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 62, in <module>
#     main()
#   File "/content/web.py", line 43, in main
#     for columns in st.sidebar.multiselect(columns):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: MultiSelectMixin.multiselect() missing 1 required positional argument: 'options'
# 2024-07-02 19:50:39.396 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 62, in <module>
#     main()
#   File "/content/web.py", line 43, in main
#     for columns in st.sidebar.multiselect(columns):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/metrics_util.py", line 408, in wrapped_func
#     result = non_optional_func(*args, **kwargs)
# TypeError: MultiSelectMixin.multiselect() missing 1 required positional argument: 'options'
# 2024-07-02 19:51:10.579 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:51:43.335 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:51:48.744 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:52:19.556 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:53:02.058 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:53:08.468 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:53:16.375 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 19:53:16.376 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 63, in <module>
#     main()
#   File "/content/web.py", line 57, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 19, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: ''
# 2024-07-02 19:53:21.768 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 19:53:21.769 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 63, in <module>
#     main()
#   File "/content/web.py", line 57, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 19, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: ''
# 2024-07-02 19:53:22.656 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 19:53:22.657 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 63, in <module>
#     main()
#   File "/content/web.py", line 57, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 19, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: ''
# 2024-07-02 19:54:10.711 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     st.success(survive)
# NameError: name 'survive' is not defined
# 2024-07-02 19:54:21.425 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:54:27.704 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:54:34.220 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:54:40.097 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# 2024-07-02 19:54:46.593 `label` got an empty value. This is discouraged for accessibility reasons and may be disallowed in the future by raising an exception. Please provide a non-empty label and hide it with label_visibility if needed.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2024-07-02 19:55:59.997 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 55, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 17, in survival_prediction
#     prediction=model.predict(b)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 820, in predict
#     proba = self.predict_proba(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 862, in predict_proba
#     X = self._validate_X_predict(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 602, in _validate_X_predict
#     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 565, in _validate_data
#     X = check_array(X, input_name="X", **check_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# ValueError: could not convert string to float: ''
# 2024-07-02 19:58:55.180 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 41, in main
#     Parch=st.num_input('Parch',0,5)
# AttributeError: module 'streamlit' has no attribute 'num_input'
# 2024-07-02 20:01:06.197 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 59, in <module>
#     main()
#   File "/content/web.py", line 54, in main
#     survive=survival_prediction([Age,SibSp,Pclass,Parch,PassengerId,Sex,Fare,Embarked])
#   File "/content/web.py", line 28, in survival_prediction
#     if (prediction[0] == 0):
# UnboundLocalError: local variable 'prediction' referenced before assignment
# 2024-07-02 20:02:43.267 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 60, in <module>
#     main()
#   File "/content/web.py", line 29, in main
#     Pclass=st.b('Pclass',0,5)
# AttributeError: module 'streamlit' has no attribute 'b'
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [0]
# 2024-07-02 20:05:27.805 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 61, in <module>
#     main()
#   File "/content/web.py", line 57, in main
#     time.sleep(3)
# NameError: name 'time' is not defined
# 2024-07-02 20:06:43.201 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/content/web.py", line 61, in <module>
#     main()
#   File "/content/web.py", line 57, in main
#     time.sleep(3)
# NameError: name 'time' is not defined
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [0]
#   Stopping...
# ^C
